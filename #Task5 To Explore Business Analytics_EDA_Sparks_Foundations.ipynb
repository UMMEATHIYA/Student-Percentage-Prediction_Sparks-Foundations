# %% [markdown]
# <b style="color:Green;font-size:32px;">Sparks Foundation - Data Science & Analytics Internship!</b><br>
# <b style="color:#ff3333;font-size:19px;">#Task_5 - To Explore Business Analytics
# (Level - Beginner & Intermediate)</b><br>
# <b style="font-size:17px;">Description of the task_5:-</b><br>
# <ul style="font-size:15px;line-height:18px;"><b><li>Perform ‘Exploratory Data Analysis’ on the provided dataset
# ‘SampleSuperstore’ </li>
# <li>As a business manager, try to find out the weak areas where you can work
# to make more profit. </li>
#     <li>What all business problems you can derive by exploring the data? </li>
#     <li>Dataset:<a> https://bit.ly/3i4rbWl</a></li></b>
# <li><b> Github Link <a>https://github.com/UMMEATHIYA/Student-Percentage-Prediction_Sparks-Foundations</a></li></b>
# </ul>

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Importing the Libraries!</b>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Reading the data from .CSV File!</b>

# %%
df = pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">describe()</b><br>Pandas describe() is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values.

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">info()</b><br>
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Checking for Null values or Missing values!</b>

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Profit'].max()
# Out:
# 8399.976

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(15,12))
plt.bar('Sub-Category','Category',data=df,color='green')
plt.show()

# %%
plt.figure(figsize=(8,6))
df['Segment'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
plt.figure(figsize=(10,8))
df['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Rel Plot</b><br>
# This function provides access to several different axes-level functions that show the relationship between two variables with semantic mappings of subsets. The kind parameter selects the underlying axes-level function to use:
#
# scatterplot() (with kind="scatter"; the default)
#
# lineplot() (with kind="line")

# %%
sns.relplot(
    data=df,
    x="Profit", y="Sales", col="Category",
    hue="Category",
)

# %% [markdown]
# <h2 style="color:green;">API abstraction across visualizations</h2>
# There is no universally best way to visualize data. Different questions are best answered by different plots. Seaborn makes it easy to switch between different visual representations by using a consistent dataset-oriented API.
#
# The function <b>relplot()</b> is named that way because it is designed to visualize many different statistical relationships. While scatter plots are often effective, relationships where one variable represents a measure of time are better represented by a line. The <b>relplot()</b> function has a convenient kind parameter that lets you easily switch to this alternate representation:

# %%
sns.relplot(
    data=df, kind="line",
    x="Profit", y="Sales", col="Category",
    hue="Category",
    facet_kws=dict(sharex=False),
)

# %% [markdown]
# <h2 style="color:green;">Statistical estimation</h2>
# Many seaborn functions will automatically perform the statistical estimation that is necessary to answer the task related questions.

# %%
sns.lmplot(data=df, x="Profit", y="Sales", col="Category", hue="Category")

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Pair Plot-Seaborn</b><br>
# <li>To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function.</li> <li>This shows the relationship for (n, 2) combination of variable in a DataFrame as a matrix of plots and the diagonal plots are the univariate plots.</li>

# %%
sns.pairplot(df, hue="Category")

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Correlation</b><br>
# <li>Correlation is a statistical technique that can show whether and how strongly pairs of variables are related.</li><br><br>
# <b style="color:DarkGreen;font-size:20px;">HeatMap</b><br>
# <li>A heat map (or heatmap) is a graphical representation of data where values are depicted by color. Heat maps make it easy to visualize complex data.</li>

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
df1= df.drop("Postal Code",axis=1)
fig=plt.figure(figsize=(8,6))
sns.heatmap(df1.corr(),linewidths=1,annot=True)

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Area Chart</b><br>
# <li>An area chart represents the change in a one or more quantities over time. It's made by plotting a series of data points over time, connecting those data points with line segments, and then filling in the area between the line and the x-axis with color or shading.</li><br><br>

# %%
df5 = df.groupby('Region')['Quantity','Profit','Sales','Discount'].agg(['sum']).plot.area(stacked=True)
plt.title('Total Profit and Sales per Region')
plt.show()
# Out:
# C:\Users\Admin\anaconda3\envs\venv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df['Cost']=df['Sales']-df['Profit']
df['Cost']
# Out:
# 0        220.0464
# 1        512.3580
# 2          7.7486
# 3       1340.6085
# 4         19.8516
#           ...
# 9989      21.1452
# 9990      76.3268
# 9991     239.1828
# 9992      16.2800
# 9993     170.2120
# Name: Cost, Length: 9994, dtype: float64

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Profit % Computation and making a new column of values in the dataframe</b><br>

# %%
df['Profit %']=(df['Profit']/df['Cost'])*100

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit       Cost   Profit %
# 0      0.00   41.9136   220.0464  19.047619
# ...

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">dtypes()</b><br>
# <li>This method is used to understand the datatype of each attribute in the dataset and if required converting them to categorical values as well!</li>

# %%
df.dtypes
# Out:
# Ship Mode         object
# Segment         category
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region          category
# Category        category
# Sub-Category      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# Cost             float64
# Profit %         float64
# dtype: object

# %%
df["Segment"] = df["Segment"].astype('category')
df["Region"] = df["Region"].astype('category')
df["Category"] = df["Category"].astype('category')
df.dtypes
# Out:
# Ship Mode         object
# Segment         category
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region          category
# Category        category
# Sub-Category      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# Cost             float64
# Profit %         float64
# dtype: object

# %%
#df["Ship Mode_cat"] = df["Ship Mode"].cat.codes
#df["Segmen_cat"] = df["Segment"].cat.codes
#df["Region_cat"] = df["Region"].cat.codes
#df["Category_cat"] = df["Category"].cat.codes
#df.head()

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Machine Learning Algorithms</b><br>
# <b style="font-size:18px;"><li>Decision Tree Regressor</li>
# <li>Linear Regression</li>
# <li>Random Forest Regressor</li>
# </b>

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
df2 = df.drop(['Ship Mode','Segment','Country','City','State','Postal Code','Category','Sub-Category','Profit %'],axis=1)

# %%
x = df2[['Quantity','Cost']]
y = df2['Sales']

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Decision Tree Regressor Algorithm</b><br>

# %% [markdown]
# <b style="color:DarkGreen;font-size:18px;">Model Fitting using Decision Tree Regressor</b><br>

# %%
(train_inputs, test_inputs, train_classes, test_classes) = train_test_split(x, y, train_size=0.7, test_size=0.3,random_state=50)
declf = DecisionTreeRegressor()
declf.fit(train_inputs, train_classes)
# Out:
# DecisionTreeRegressor()

# %%
predictions = declf.predict(train_inputs)

# %%
new_inputs = [[3,512.3580]]
predictions = declf.predict(new_inputs)
predictions
# Out:
# array([640.4475])

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Decision Tree Regressor Training and Testing Accuracy</b><br>

# %%
print("Accuracy of Training of Decision Tree -",declf.score(train_inputs, train_classes)*100)
print("Accuracy of Testing of Decision Tree -",declf.score(test_inputs, test_classes)*100)
# Out:
# Accuracy of Training of Decision Tree - 98.16228623636826
# Accuracy of Testing of Decision Tree - 80.48077106539746

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Linear Regressor Algorithm</b><br>

# %%
from sklearn.linear_model import LinearRegression
linearRegressor= LinearRegression()
linearRegressor.fit(train_inputs, train_classes)
predictions = declf.predict(train_inputs)

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Model Fitting using Linear Regression</b><br>

# %%
lr = [[3,512.3580]]
predictions = linearRegressor.predict(lr)
predictions
# Out:
# array([547.65388963])

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Linear Regression Training and Testing Accuracy</b><br>

# %%
print("Accuracy of Training of  Linear Regression -",linearRegressor.score(train_inputs, train_classes)*100)
print("Accuracy of Testing of Linear Regression -",linearRegressor.score(test_inputs, test_classes)*100)
# Out:
# Accuracy of Training of  Linear Regression - 86.06709917979366
# Accuracy of Testing of Linear Regression - 86.08874388847761

# %% [markdown]
# <b style="color:DarkGreen;font-size:20px;">Random Forest Regressor Algorithm</b><br>

# %% [markdown]
# <b style="color:DarkGreen;font-size:18px;">Model Fitting using Random Forest Regressor</b><br>

# %%
from sklearn.ensemble import RandomForestRegressor  
regressor = RandomForestRegressor(n_estimators = 250, random_state = 82) 
regressor.fit(train_inputs, train_classes)
# Out:
# RandomForestRegressor(n_estimators=250, random_state=82)

# %%
Y_pred = regressor.predict(train_inputs)

# %%
rf = [[3,512.3580]]
predictions = regressor.predict(rf)
predictions
# Out:
# array([635.61133661])

# %%
print("Accuracy of Training of  Random Forest Regression -",regressor.score(train_inputs, train_classes)*100)
print("Accuracy of Testing of Random Forest Regression -",regressor.score(test_inputs, test_classes)*100)
# Out:
# Accuracy of Training of  Random Forest Regression - 95.12804743454465
# Accuracy of Testing of Random Forest Regression - 86.2266256285977

# %%
from IPython.core.display import HTML
HTML('''<div class="flourish-embed flourish-hierarchy" data-src="visualisation/4051236" data-url="https://flo.uri.sh/visualisation/4051236/embed" aria-label=""><script src="https://public.flourish.studio/resources/embed.js"></script></div>''')
# Out:
# <div class="flourish-embed flourish-hierarchy" data-src="visualisation/4051236" data-url="https://flo.uri.sh/visualisation/4051236/embed" aria-label=""><script src="https://public.flourish.studio/resources/embed.js"></script></div>

# %%
HTML('''<div class="flourish-embed flourish-hierarchy" data-src="visualisation/4050858" data-url="https://flo.uri.sh/visualisation/4050858/embed" aria-label=""><script src="https://public.flourish.studio/resources/embed.js"></script></div>''')
# Out:
# <div class="flourish-embed flourish-hierarchy" data-src="visualisation/4050858" data-url="https://flo.uri.sh/visualisation/4050858/embed" aria-label=""><script src="https://public.flourish.studio/resources/embed.js"></script></div>
